# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --db uk_food --collection establishments --drop --file "C:\Users\wware\Desktop\UWA Bootcamp\Challenges\nosql-challenge\Resources\establishments.json" --jsonArray`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
databases = mongo.list_database_names()

print(databases)
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'uk_food']

# %%
# Another way of checking if the database was created
if 'uk_food' in databases:
    print("uk_food database exists")
else:
    print("uk_food database does not exist")
# Out:
# uk_food database exists

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
collections = db.list_collection_names()

print(collections)
# Out:
# ['establishments']

# %%
# Another way of checking if the collections

for collection in collections:
    print("The collections in uk_food are: ")
    print(collection)
# Out:
# The collections in uk_food are:
# establishments

# %%
# Review a document in the establishments collection
# Assign the collection to a variable name
establishments = db['establishments']

# Find the first document in the collection
print("The first document in the establishments collection is: ")
pprint(establishments.find_one())
# Out:
# The first document in the establishments collection is:
# {'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Coastguard Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4587.347174863443,
#  'FHRSID': 1034540,
#  'LocalAuthorityBusinessID': 'PI/000078691',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DY',
#  'RatingDate': '2022-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1893'),
#  'geocode': {'latitude': '51.152225', 'longitude': '1.387974'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1034540',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Check if Penang Flavours already exists in the establishments collection
existing_establishment = establishments.find_one({"BusinessName": "Penang Flavours"})

if existing_establishment:
    print("Penang Flavours already exists in the establishments collection")
    pprint(existing_establishment)
else:
    print("You will need to add Penang Flavours to the establishments collection")
# Out:
# You will need to add Penang Flavours to the establishments collection

# %%
from bson import ObjectId

template = {
    'AddressLine1': '',  # String (Placeholder)
    'AddressLine2': '',  # String (Placeholder)
    'AddressLine3': '',  # String (Placeholder)
    'AddressLine4': '',  # String (Placeholder)
    'BusinessName': '',  # String (Placeholder)
    'BusinessType': '',  # String (Placeholder)
    'BusinessTypeID': '',  # String (Placeholder)
    'ChangesByServerID': 0,  # Integer (Placeholder)
    'Distance': 0.0,  # Float (Placeholder)
    'FHRSID': '',  # String (Placeholder)
    'LocalAuthorityBusinessID': '',  # String (Placeholder)
    'LocalAuthorityCode': '',  # String (Placeholder)
    'LocalAuthorityEmailAddress': '',  # String (Placeholder)
    'LocalAuthorityName': '',  # String (Placeholder)
    'LocalAuthorityWebSite': '',  # String (URL)
    'NewRatingPending': False,  # Boolean (Placeholder)
    'Phone': '',  # String (Placeholder)
    'PostCode': '',  # String (Placeholder)
    'RatingDate': '',  # String (ISO 8601 Date Format)
    'RatingKey': '',  # String (Placeholder)
    'RatingValue': '',  # String (Placeholder "1 to 10")
    'RightToReply': '',  # String (Placeholder)
    'SchemeType': 'FHRS',  # String (Placeholder)
    '_id': ObjectId(),  # ObjectId (Automatically generated)
    'geocode': {
        'latitude': 0.0,  # String (Placeholder, should be Float)
        'longitude': 0.0  # String (Placeholder, should be Float)
    },
    'links': [
        {
            'href': '',  # String (URL)
            'rel': 'self'  # String (Relationship type)
        }
    ],
    'meta': {
        'dataSource': None,  # NoneType
        'extractDate': '0001-01-01T00:00:00',  # String (ISO 8601 Date Format)
        'itemCount': 0,  # Integer (Placeholder)
        'pageNumber': 0,  # Integer (Placeholder)
        'pageSize': 0,  # Integer (Placeholder)
        'returncode': None,  # NoneType
        'totalCount': 0,  # Integer (Placeholder)
        'totalPages': 0  # Integer (Placeholder)
    },
    'scores': {
        'ConfidenceInManagement': 0,  # Integer (Placeholder)
        'Hygiene': 0,  # Integer (Placeholder)
        'Structural': 0  # Integer (Placeholder)
    }
}

# %%
# To generate a full copy for a nested dictionary
from copy import deepcopy

# Create a function to start a new restaurant entry into the database
# Function to create a new restaurant entry
def create_restaurant_entry(details):
    # Copy the template to avoid modifying the original
    new_restaurant = deepcopy(template)
    
    # Update the template with the provided details
    new_restaurant.update(details)
    
    # Insert the new restaurant into the establishments collection
    try:
        establishments.insert_one(new_restaurant)
        print(f"Inserted new restaurant: {new_restaurant['BusinessName']}")
    except Exception as e:
        print(f"Error inserting new restaurant: {e}")
    
    # Return the new restaurant document
    return new_restaurant

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
# If the restaurant does not exist, add it to the collection
if not existing_establishment:
    create_restaurant_entry(new_restaurant)
# Out:
# Inserted new restaurant: Penang Flavours

# %%
# Check that the new restaurant was inserted
print("Inserted and retrieved new restaurant: ")
pprint(establishments.find_one({"BusinessName": "Penang Flavours"}))
# Out:
# Inserted and retrieved new restaurant:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'ChangesByServerID': 0,
#  'Distance': 4623.972328074718,
#  'FHRSID': '',
#  'LocalAuthorityBusinessID': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingDate': '',
#  'RatingKey': '',
#  'RatingValue': '',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e76676995216d2e0beac0'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'links': [{'href': '', 'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {"BusinessType": "Restaurant/Cafe/Canteen"}

result = establishments.find_one(query, {"BusinessTypeID": 1, "BusinessType": 1, "_id": 0})

if result:
    print("Found the following BusinessTypeID for 'Restaurant/Cafe/Canteen': ")
    pprint(result)
else:
    print("Could not find the BusinessTypeID for 'Restaurant/Cafe/Canteen'")
# Out:
# Found the following BusinessTypeID for 'Restaurant/Cafe/Canteen':
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}

# %%
# 3. Update the new restaurant with the `BusinessTypeID` you found using the previous query - looking at other results in the collection.
restaurant_query = {"BusinessName": "Penang Flavours"}

update = {"$set": {"BusinessTypeID": result["BusinessTypeID"]}}
update_result = establishments.update_one(restaurant_query, update)

# %%
# Confirm that the new restaurant was updated
if update_result.matched_count > 0:
    print("Updated the new restaurant with BusinessTypeID.")
    pprint(establishments.find_one(restaurant_query))
else:
    print("Failed to find the new restaurant to update.")
# Out:
# Updated the new restaurant with BusinessTypeID.
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4623.972328074718,
#  'FHRSID': '',
#  'LocalAuthorityBusinessID': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingDate': '',
#  'RatingKey': '',
#  'RatingValue': '',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e76676995216d2e0beac0'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'links': [{'href': '', 'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_count = establishments.count_documents({"LocalAuthorityName": "Dover"})

# Print the number of documents with LocalAuthorityName as "Dover"
print(f"There are {dover_count} documents with LocalAuthorityName as 'Dover'")
# Out:
# There are 994 documents with LocalAuthorityName as 'Dover'

# %%
# Delete all documents where LocalAuthorityName is "Dover"
delete_result = establishments.delete_many({"LocalAuthorityName": "Dover"})

# Print the number of documents that were deleted
print(f"Deleted {delete_result.deleted_count} documents with LocalAuthorityName as 'Dover'")
# Out:
# Deleted 994 documents with LocalAuthorityName as 'Dover'

# %%
# Check if any remaining documents include Dover
# Find how many documents have LocalAuthorityName as "Dover"
dover_count_second = establishments.count_documents({"LocalAuthorityName": "Dover"})

# Print the number of documents with LocalAuthorityName as "Dover"
print(f"There are {dover_count_second} documents with LocalAuthorityName as 'Dover'")
# Out:
# There are 0 documents with LocalAuthorityName as 'Dover'

# %%
# Check that other documents remain with 'find_one'
any_doc_remaining = establishments.find_one()

if any_doc_remaining:
    print("There are still documents in the collection.")
    pprint(any_doc_remaining)
else:
    print("There are no documents in the collection.")
# Out:
# There are still documents in the collection.
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b75'),
#  'geocode': {'latitude': '51.086058', 'longitude': '1.196408'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
# Longitude conversion
establishments.update_many(
    {"geocode.longitude": {"$type": "string"}},
    [{'$set': {"geocode.longitude": {"$toDouble": "$geocode.longitude"}}}]
)

# Latitude conversion
establishments.update_many(
    {"geocode.latitude": {"$type": "string"}},
    [{'$set': {"geocode.latitude": {"$toDouble": "$geocode.latitude"}}}]
)

# Change verification
# Retrieve the document to check the data types of longitude and latitude
updated_doc2 = establishments.find_one()

# Check and print the data types of longitude and latitude
longitude_type = type(updated_doc2['geocode']['longitude'])
latitude_type = type(updated_doc2['geocode']['latitude'])

print(f"Data type of longitude: {longitude_type}")
print(f"Data type of latitude: {latitude_type}")
print("==========================================\n")

# Print the updated document to verify changes
print("Updated document with converted latitude and longitude:")
pprint(updated_doc2)
# Out:
# Data type of longitude: <class 'float'>
# Data type of latitude: <class 'float'>
# ==========================================
#
# Updated document with converted latitude and longitude:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b75'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values (e.g. Other) and empty strings to Null (e.g. Penang_Flavours)
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt", ""]
establishments.update_many(
    {"RatingValue": {"$in": non_ratings}},
    {"$set": {"RatingValue": None}}
)

# Convert RatingValue from String to Integer for numeric values
establishments.update_many(
    {"RatingValue": {"$regex": "^[0-9]+$"}},
    [{"$set": {"RatingValue": {"$toInt": "$RatingValue"}}}]
)

# Change verification (for a restaurant with a rating value)
updated_doc3 = establishments.find_one()

# Check and print the data types of RatingValue
rating_value_type = type(updated_doc3['RatingValue'])

print(f"Data type of RatingValue: {rating_value_type}")
print("==========================================\n")

# Print the updated document to verify changes
print("Updated document with converted rating value:")
pprint(updated_doc3)
# Out:
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# Updated document with converted rating value:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b75'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %%
# Change verification (for Penang_Flavours, which should be a None type)
updated_doc4 = establishments.find_one({"BusinessName": "Penang Flavours"})

# Check and print the data types of RatingValue
rating_value_type = type(updated_doc4['RatingValue'])

print(f"Data type of RatingValue: {rating_value_type}")
print("==========================================\n")

# Print the updated document to verify changes
print("Updated document with converted rating value:")
pprint(updated_doc4)
# Out:
# Data type of RatingValue: <class 'NoneType'>
# ==========================================
#
# Updated document with converted rating value:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 0.0,
#  'FHRSID': '',
#  'LocalAuthorityBusinessID': '',
#  'LocalAuthorityCode': '',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingDate': '',
#  'RatingKey': '',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666bc8c64e941ff25bb1e101'),
#  'geocode': {'latitude': 0.0, 'longitude': 0.0},
#  'links': [{'href': '', 'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# Check that the coordinates and rating value are now numbers
# Retrieve a sample of documents to check the data types
documents = establishments.find().limit(100)

# Iterate through the docs and check the data types
for doc in documents:
    latitude_type = type(doc['geocode']['latitude'])
    longitude_type = type(doc['geocode']['longitude'])
    rating_value_type = type(doc['RatingValue'])
    
    print(f"Document ID: {doc['_id']}")
    print(f"Data type of latitude: {latitude_type}")
    print(f"Data type of longitude: {longitude_type}")
    print(f"Data type of RatingValue: {rating_value_type}")
    print("==========================================\n")
    
    # Print the document to verify changes (optional)
    pprint(doc)
    print("\n")

# Check the total number of documents to verify the process
total_documents = establishments.count_documents({})
print(f"Total number of documents in the collection: {total_documents}")
# Out:
# Document ID: 666e760f2390fdff640d1b75
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b75'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b78
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4591.871474174837,
#  'FHRSID': 289353,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6QH',
#  'RatingDate': '2016-09-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b78'),
#  'geocode': {'latitude': 51.085797, 'longitude': 1.194762},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289353',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1b79
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': '16 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Mariner',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 289560,
#  'LocalAuthorityBusinessID': 'PI/000039927',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2019-03-19T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b79'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289560',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b7a
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b7a'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b7b
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': '23 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Ship',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 289352,
#  'LocalAuthorityBusinessID': 'PI/000002460',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2015-08-27T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b7b'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289352',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b80
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': '1 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Folkestone Trawlers Shop',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 344689,
#  'LocalAuthorityBusinessID': 'PI/000002095',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2020-02-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b80'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/344689',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b81
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'The Ship',
#  'AddressLine2': '23 The Stade',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Ships Galley',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 987206,
#  'LocalAuthorityBusinessID': 'PI/000075655',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2019-07-03T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b81'),
#  'geocode': {'latitude': 51.08084, 'longitude': 1.188537},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/987206',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1b83
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Docker',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 894592,
#  'LocalAuthorityBusinessID': 'PI/000074396',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-04-18T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b83'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/894592',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1b84
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Pick Up Pintxos',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1043701,
#  'LocalAuthorityBusinessID': 'PI/000076360',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-04-18T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b84'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043701',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b85
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Dr Legumes - Harbour Arm',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 805702,
#  'LocalAuthorityBusinessID': 'PI/000073219',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-06-08T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b85'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/805702',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}}
#
#
# Document ID: 666e760f2390fdff640d1b86
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'That Burger - Harbour Arm',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 805703,
#  'LocalAuthorityBusinessID': 'PI/000073221',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b86'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/805703',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b87
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Tea Caddy',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1068284,
#  'LocalAuthorityBusinessID': 'PI/000076532',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-08-03T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b87'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1068284',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b88
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Little Rock',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1423242,
#  'LocalAuthorityBusinessID': 'PI/000078141',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b88'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1423242',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
#
#
# Document ID: 666e760f2390fdff640d1b89
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Club Hut',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1071930,
#  'LocalAuthorityBusinessID': 'PI/000076531',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-08-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b89'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1071930',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b8a
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Lobster & Burger',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1495230,
#  'LocalAuthorityBusinessID': 'PI/000078175',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b8a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1495230',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b8b
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Custom Folkestone',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1046418,
#  'LocalAuthorityBusinessID': 'PI/000076426',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-11-30T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b8b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1046418',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b8c
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': "Dino's",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1396944,
#  'LocalAuthorityBusinessID': 'PI/000078122',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2021-06-06T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b8c'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1396944',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b8d
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Barney & The Pizza',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1396943,
#  'LocalAuthorityBusinessID': 'PI/000078121',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2021-06-06T00:00:00',
#  'RatingKey': 'fhrs_3_en-gb',
#  'RatingValue': 3,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b8d'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1396943',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 10}}
#
#
# Document ID: 666e760f2390fdff640d1b8e
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pilot',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1299500,
#  'LocalAuthorityBusinessID': 'PI/000078051',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2021-06-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b8e'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1299500',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1b8f
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Dessert Junction',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1495226,
#  'LocalAuthorityBusinessID': 'PI/000078171',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b8f'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1495226',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1b90
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Platform Three',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1058634,
#  'LocalAuthorityBusinessID': 'PI/000076448',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-08-03T00:00:00',
#  'RatingKey': 'fhrs_3_en-gb',
#  'RatingValue': 3,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b90'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1058634',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 10}}
#
#
# Document ID: 666e760f2390fdff640d1b91
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Coffee Folkes',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1241758,
#  'LocalAuthorityBusinessID': 'PI/000077661',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-28T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b91'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1241758',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1b92
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Greek Street',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1466503,
#  'LocalAuthorityBusinessID': 'PI/000078160',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-28T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b92'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1466503',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1b93
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Hog & Hop - Harbour Arm',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 873838,
#  'LocalAuthorityBusinessID': 'PI/000074304',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2019-07-12T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b93'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/873838',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b94
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Waiting Room - Harbour Arm',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 861820,
#  'LocalAuthorityBusinessID': 'PI/000074300',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2019-07-12T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b94'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/861820',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b95
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Fish Shack',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1410251,
#  'LocalAuthorityBusinessID': 'PI/000078140',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b95'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1410251',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1b96
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Taco Shed',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1427428,
#  'LocalAuthorityBusinessID': 'PI/000078143',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2021-06-06T00:00:00',
#  'RatingKey': 'fhrs_2_en-gb',
#  'RatingValue': 2,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b96'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1427428',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 10, 'Structural': 15}}
#
#
# Document ID: 666e760f2390fdff640d1b97
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Babaji',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1058636,
#  'LocalAuthorityBusinessID': 'PI/000076450',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2021-08-13T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b97'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1058636',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
#
#
# Document ID: 666e760f2390fdff640d1b98
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Harbour Coffee Company',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1058635,
#  'LocalAuthorityBusinessID': 'PI/000076449',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2021-10-03T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b98'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1058635',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1b99
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'A Hui Hou',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1401066,
#  'LocalAuthorityBusinessID': 'PI/000078134',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2021-08-13T00:00:00',
#  'RatingKey': 'fhrs_2_en-gb',
#  'RatingValue': 2,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b99'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1401066',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 15, 'Structural': 15}}
#
#
# Document ID: 666e760f2390fdff640d1b9a
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Shesells Seashells',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1401065,
#  'LocalAuthorityBusinessID': 'PI/000078133',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2021-09-26T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b9a'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1401065',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1b9b
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Bath Tub and Gun - Harbour Arm',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 861815,
#  'LocalAuthorityBusinessID': 'PI/000073853',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2019-07-26T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1b9b'),
#  'geocode': {'latitude': 51.0783519967076, 'longitude': 1.18590330311705},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/861815',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
# ...
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1SE',
#  'RatingDate': '2021-08-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1bdd'),
#  'geocode': {'latitude': 51.079532623291, 'longitude': 1.1813759803772},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1380216',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
#
#
# Document ID: 666e760f2390fdff640d1bde
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Church Street',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'St Eanswythes Church Of England Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4592.12476224034,
#  'FHRSID': 289486,
#  'LocalAuthorityBusinessID': 'PI/000029625',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1SE',
#  'RatingDate': '2017-11-30T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1bde'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289486',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1bdf
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Ground Floor Business Premises',
#  'AddressLine2': '3 George Lane',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Hillside Restaurant',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4592.12077000758,
#  'FHRSID': 376004,
#  'LocalAuthorityBusinessID': 'PI/000029646',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1RH',
#  'RatingDate': '2020-03-12T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1bdf'),
#  'geocode': {'latitude': 51.079889, 'longitude': 1.181832},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/376004',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 10}}
#
#
# Document ID: 666e760f2390fdff640d1be0
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': '11-15 The Old High Street',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Misused Cocktails',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4592.115827007254,
#  'FHRSID': 1427423,
#  'LocalAuthorityBusinessID': 'PI/000068740',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1RL',
#  'RatingDate': '2021-11-03T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1be0'),
#  'geocode': {'latitude': 51.0802956, 'longitude': 1.1823865},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1427423',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1be1
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Ground Floor Business Premises',
#  'AddressLine2': '5 Church Street',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Folkestone Wine Company',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4592.12476224034,
#  'FHRSID': 990687,
#  'LocalAuthorityBusinessID': 'PI/000075113',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1SE',
#  'RatingDate': '2019-10-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1be1'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/990687',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1be2
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Pullman Wine Bar',
#  'AddressLine2': '7-9 Church Street',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pullman',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4592.12476224034,
#  'FHRSID': 728906,
#  'LocalAuthorityBusinessID': 'PI/000071965',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1SE',
#  'RatingDate': '2018-09-11T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1be2'),
#  'geocode': {'latitude': 51.079542, 'longitude': 1.181365},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/728906',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
#
#
# Document ID: 666e760f2390fdff640d1be3
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': '4 The Old High Street',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Super Pizza',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4592.129725943966,
#  'FHRSID': 534012,
#  'LocalAuthorityBusinessID': 'PI/000033543',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1RJ',
#  'RatingDate': '2021-06-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1be3'),
#  'geocode': {'latitude': 51.080412, 'longitude': 1.182125},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/534012',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1be4
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': '1 George Lane',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Teastones',
#  'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  'ChangesByServerID': 0,
#  'Distance': 4592.125453597161,
#  'FHRSID': 1219531,
#  'LocalAuthorityBusinessID': 'PI/000077614',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1RH',
#  'RatingDate': '2020-01-30T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1be4'),
#  'geocode': {'latitude': 51.0798931, 'longitude': 1.1817077},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1219531',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1be6
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': '5 Rendezvous Street',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Sweet Rendezvous',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4592.144852423555,
#  'FHRSID': 1292455,
#  'LocalAuthorityBusinessID': 'PI/000078049',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT20 1EY',
#  'RatingDate': '2021-07-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1be6'),
#  'geocode': {'latitude': 51.0800235, 'longitude': 1.1813097},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1292455',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
#
#
# Document ID: 666e760f2390fdff640d1be7
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Plamil House',
#  'AddressLine2': 'Bowles Well Gardens',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Kent Dark Chocolate Company',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4592.150740218588,
#  'FHRSID': 734837,
#  'LocalAuthorityBusinessID': 'PI/000072507',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PQ',
#  'RatingDate': '2018-02-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1be7'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/734837',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Document ID: 666e760f2390fdff640d1be8
# Data type of latitude: <class 'float'>
# Data type of longitude: <class 'float'>
# Data type of RatingValue: <class 'int'>
# ==========================================
#
# {'AddressLine1': 'Plamil House',
#  'AddressLine2': 'Bowles Well Gardens',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Plamil Foods Ltd',
#  'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  'ChangesByServerID': 0,
#  'Distance': 4592.150740218588,
#  'FHRSID': 289384,
#  'LocalAuthorityBusinessID': 'PI/000008109',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PQ',
#  'RatingDate': '2018-02-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('666e760f2390fdff640d1be8'),
#  'geocode': {'latitude': 51.089491, 'longitude': 1.190904},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289384',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
#
#
# Total number of documents in the collection: 38786
